# %% [markdown]
# # Stroke prognosis modeling (reproducible pipeline)
#
# This notebook is a lightweight entry point.
#
# **Recommended**: run the scripts under `./scripts/` for fully reproducible, CLI-based execution.

# %%
# !python -m pip install -r requirements.txt

# %% [markdown]
# ## 1) Train + compare models
# Place your dataset under `data/` (Excel/CSV). Ensure a binary label column exists (0/1).

# %%
# !python scripts/train_compare_models.py --data data/train.xlsx --label_col outcome --out_dir outputs/model_comparison

# %% [markdown]
# ## 2) DeLong test (pairwise)
# Use the exported probability file.

# %%
# !python scripts/run_delong.py --pred outputs/model_comparison/predictions_for_delong.xlsx --a XGBoost --b LogisticRegression
